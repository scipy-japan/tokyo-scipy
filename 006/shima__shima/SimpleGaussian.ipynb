# %% [markdown]
# # 単純なガウス分布の平均パラメータの推定
#
# ## 準備作業
#
# まずいろいろ必要なものの import
#
# %matplotlibのインライン指定もしておく

# %%
import numpy as np
import matplotlib.pyplot as plt
from pymc import Normal, deterministic, MCMC, Matplot
# %matplotlib inline

# %% [markdown]
# ### 平均パラメータ \\(\mu\\) の事前分布
#
# \\(x\\) を生成する正規分布の平均は \\(\mu\\)．この \\(\mu\\) の事前分布は，平均が 0 で，分散が \\(1/0.01\\)．
# とりあえずどんな感じの分布になるかプロットしておく

# %%
mu = np.random.normal(0.0, 0.01, 100)
plt.hist(mu)
# Out:
# (array([  4.,   6.,  13.,  13.,  16.,  19.,  11.,  10.,   3.,   5.]),
#  array([ -2.51154146e-02,  -2.00931763e-02,  -1.50709380e-02,
#          -1.00486997e-02,  -5.02646140e-03,  -4.22308565e-06,
#           5.01801523e-03,   1.00402535e-02,   1.50624919e-02,
#           2.00847302e-02,   2.51069685e-02]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 訓練用サンプルデータの生成
#
# `x_sample` は学習用のサンプル．
# 平均が 1.0 で，標準偏差が 1.0 の正規分布に従う．
# まずは少数のサンプル 5 個だけでやってみる．
#
# \\(\mu\\) が 1.0 を中心に分布するようになれば成功

# %%
x_sample = np.random.normal(loc=1.0, scale=1.0, size=5)

# %% [markdown]
# ## パラメータの事後確率の推定
#
# ### モデルの構築
#
# 生成モデルは，非常に単純：
# \\[
# \mu\sim\mathrm{Normal}(0, 1/0.01)
# \\]
# \\[
# x\sim\mathrm{Normal}(\mu, 1/1.0)
# \\]
#
# ※ NumPy の np.random.normal は平均と標準偏差で指定するが，PyMC の正規分布は，標準偏差ではなく精度（分散の逆数・逆行列）で指定する
#
# \\(x\\) は，平均が \\(\mu\\) で，分散が \\(1/0.01\\) としておく．この \\(x\\) については標本が観測される（グラフィカルモデルでいえば黒丸）ので，  `value=x_sample` と `observed=True` を指定しておく．

# %%
mu = Normal('mu', 0, 0.01)
x = Normal('p', mu=mu, tau=1.0, value=x_sample, observed=True)

# %% [markdown]
# ### MCMCによる事後確率の推定
#
# マルコフ連鎖のモデルを指定．超初心者なので，最適化パラメータの意味とかは分かってないが，とりあえず， `input` に関連する変数を入れておいて，適当な回数だけ反復してみる

# %%
M = MCMC(input=[mu, x])
M.sample(iter=10000)
# Out:
#  [-----------------96%----------------  ] 9632 of 10000 complete in 0.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 0.5 sec

# %% [markdown]
# 左上はサンプリング中の \\(\mu\\) の値，左下は自己相関で収束してるかどうかを見る．右が \\(\mu\\) のデータを観測したあとのパラメータの事後分布

# %%
Matplot.plot(mu)
# Out:
# Plotting mu

# %% [markdown]
# ### サンプル数を増やして事前分布の影響を弱める
#
# 今度は同じモデルで，サンプル数をガーンと100個までふやしてみる．

# %%
x_sample = np.random.normal(loc=1.0, scale=1.0, size=100)
mu = Normal('mu', 0, 0.01)
x = Normal('p', mu=mu, tau=1.0, value=x_sample, observed=True)

# %%
M = MCMC(input=[mu, x])
M.sample(iter=10000)
# Out:
#  [-----------------91%--------------    ] 9165 of 10000 complete in 0.5 sec
#  [-----------------100%-----------------] 10000 of 10000 complete in 0.5 sec

# %% [markdown]
# すると \\(\mu\\) の事後分布がずっと1.0の周囲で尖った分布になってる．すなわち，事前分布の影響が減ってデータに合わせた分布になってることが分かる．

# %%
Matplot.plot(mu)
# Out:
# Plotting mu
